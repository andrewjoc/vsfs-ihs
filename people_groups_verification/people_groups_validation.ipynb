# %%
# Useful library imports
import pandas as pd
import geopandas as gpd
import folium
import os
import zipfile
from shapely import *
import numpy as np

# functions to process PeopleGroups datasets
from features import *

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />

# %% [markdown]
# # Load Data

# %% [markdown]
# def validate_ppg(ppg_areas_gdf, country, adm1_name):
#     """
#     Determines if people group's has accurate population counts in a country.
#     1: GeoDataFrame
#     2: String
#     3: String
#     """
#
#     # arbitrarily change Coordinate Reference System (CRS) to be the same (4326)
#     ppg_areas_gdf = ppg_areas_gdf.to_crs(4326)
#
#     # LOADING DATA -- find data for a country and load shapes
#     ppg_df = find_ppg_data(country)
#     shapes = gpd.read_file('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/cgaz.topojson').set_crs("EPSG:4326")
#     populations = pd.read_csv('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/subnationalPopulation.csv')
#
#     # MERGE -- merge people points with people areas
#     full_people_df = ppg_df.merge(ppg_areas_gdf, how='left', left_on='People Group', right_on='NmDisp')
#
#     # MERGE -- merge full df with subnational population data
#     # DO LATER!!!
#
#
#     boundaries = []
#     for people_polygon in ppg_gdf.geometry:
#         # true false series
#         overlapping_polygons = shapes.geometry.overlaps(people_polygon)
#
#         # from stack overflow - select series indices based on True values
#         indices = overlapping_polygons[overlapping_polygons].index.values
#
#         # select the names of the boundaries
#         all_boundaries_found = shapes.iloc[indices].shapeName.tolist()
#
#         if len(all_boundaries_found) == 0:
#             boundaries.append('NONE')
#         else:
#             # stored in a string to make it look nice in the DataFrame
#             boundaries_string = ', '.join(all_boundaries_found)
#             boundaries.append(boundaries_string)
#
#     ppg_gdf[f'{adm1_name}s Present'] = boundaries
#     # filter out the NONE values
#
#
#     return ppg_gdf[ppg_gdf[f'{adm1_name}s Present'] != 'NONE']

# %% [markdown]
# cell below takes a minute or 2 to load

# %%
boundaries = gpd.read_file('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/cgaz.topojson')

populations = pd.read_csv('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/subnationalPopulation.csv')

people_points = pd.read_excel('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/People_Groups.xlsx')

people_areas = gpd.read_file('data/people_areas.geojson')

# %%
validate_ppg(people_areas, country="Indonesia", adm1_name="Regency")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 validate_ppg(people_areas, country="Indonesia", adm1_name="Regency")
#
# File ~/Desktop/projects/IHS/people_groups_verification/features.py:149, in validate_ppg(ppg_areas_gdf, country, adm1_name)
#     146 boundaries = []
#     147 for people_polygon in full_people_df.geometry:
#     148     # true false series
# --> 149     overlapping_polygons = shapes.geometry.overlaps(people_polygon)
#     151     # from stack overflow - select series indices based on True values
#     152     indices = overlapping_polygons[overlapping_polygons].index.values
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/base.py:1532, in GeoPandasBase.overlaps(self, other, align)
#    1423 def overlaps(self, other, align=True):
#    1424     """Returns True for all aligned geometries that overlap *other*, else False.
#    1425
#    1426     Geometries overlaps if they have more than one but not all
#    (...)
#    1530
#    1531     """
# -> 1532     return _binary_op("overlaps", self, other, align)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/base.py:59, in _binary_op(op, this, other, align, *args, **kwargs)
#      56 def _binary_op(op, this, other, align, *args, **kwargs):
#      57     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      58     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 59     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      60     return Series(data, index=index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/base.py:41, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      39     a_this = GeometryArray(this.values)
#      40 else:
# ---> 41     raise TypeError(type(this), type(other))
#      43 data = getattr(a_this, op)(other, *args, **kwargs)
#      44 return data, this.index
#
# TypeError: (<class 'geopandas.geoseries.GeoSeries'>, <class 'NoneType'>)

# %% [markdown]
# <br>

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />

# %% [markdown]
# # Validation: Southeast Asia

# %% [markdown]
# ## Countries
# * Brunei
# * Cambodia
# * Indonesia
# * Laos
# * Malaysia
# * Myanmar
# * Philippines
# * Singapore
# * Thailand
# * Timor-Leste
# * Vietnam

# %%
# arbitrarily change Coordinate Reference System (CRS) to be the same (4326)
people_areas = people_areas.to_crs(4326) 
    
# LOADING DATA -- find data for a country and load shapes
ppg_df = find_ppg_data("Indonesia")
shapes = gpd.read_file('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/cgaz.topojson').set_crs("EPSG:4326")
populations = pd.read_csv('https://github.com/andrewjoc/ihs/raw/main/people_groups_verification/data/subnationalPopulation.csv')    
    
    # MERGE -- merge people points with people areas
full_people_df = ppg_df.merge(people_areas, how='left', left_on='People Group', right_on='NmDisp')
full_people_df = gpd.GeoDataFrame(full_people_df, crs=4326)
full_people_df.dropna(subset=['geometry'], inplace=True)
    
# MERGE -- merge full df with subnational population data
# DO LATER!!!

boundaries = []
for people_polygon in full_people_df.geometry:
    # true false series
    overlapping_polygons = shapes.geometry.overlaps(people_polygon)
        
    # from stack overflow - select series indices based on True values
    indices = overlapping_polygons[overlapping_polygons].index.values
        
    # select the names of the boundaries
    all_boundaries_found = shapes.iloc[indices].shapeName.tolist()
        
    if len(all_boundaries_found) == 0:
        boundaries.append('NONE')
    else:
        # stored in a string to make it look nice in the DataFrame
        boundaries_string = ','.join(all_boundaries_found)
        boundaries.append(boundaries_string)

        
full_people_df[f'ADM1 overlap'] = boundaries
    # filter out the NONE values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # arbitrarily change Coordinate Reference System (CRS) to be the same (4326)
# ----> 2 people_areas = people_areas.to_crs(4326)
#       4 # LOADING DATA -- find data for a country and load shapes
#       5 ppg_df = find_ppg_data("Indonesia")
#
# NameError: name 'people_areas' is not defined

# %%
shapes.head()
# Out:
#      id ISO_CODE shapeName LEVEL Level                    shapeID shapeGroup  \
# 0  None     None      None  ADM1  None  AFG-ADM1-8247537B41623266        AFG
# 1  None     None      None  ADM1  None  AFG-ADM1-8247537B78184625        AFG
# 2  None     None      None  ADM1  None  AFG-ADM1-8247537B74530288        AFG
# 3  None     None      None  ADM1  None  AFG-ADM1-8247537B30575277        AFG
# 4  None     None      None  ADM1  None  AFG-ADM1-8247537B29636249        AFG
#
#   shapeType                                           geometry
# 0      ADM1  POLYGON ((71.19492 36.03916, 71.17004 36.02439...
# 1      ADM1  POLYGON ((64.70638 35.21291, 64.72793 35.18542...
# 2      ADM1  POLYGON ((69.21919 36.30379, 69.21190 36.28759...
# 3      ADM1  POLYGON ((68.18924 36.56585, 68.18498 36.54288...
# 4      ADM1  POLYGON ((68.08847 35.46823, 68.08538 35.45314...

# %%
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

wikiurl = 'https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes'
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)

soup = BeautifulSoup(response.text, 'html.parser')
indiatable = soup.find('table',{'class':"wikitable"})

iso_country_codes = pd.read_html(str(indiatable))

# convert list to dataframe
iso_country_codes = pd.DataFrame(iso_country_codes[0]).droplevel(0, axis=1).rename({'Country name[5]':'Country', 'Alpha-3 code[5]':'Alpha 3 code'}, axis=1)

iso_country_codes = iso_country_codes[['Country', 'Alpha 3 code']]

# %%
shapes.merge(iso_country_codes, left_on='shapeGroup', right_on='Alpha 3 code', how='left').drop(['LEVEL', 'Alpha 3 code'], axis=1).dropna(subset='Country').drop('geometry', axis=1)
# Out:
#         id ISO_CODE shapeName Level                    shapeID shapeGroup  \
# 0     None     None      None  None  AFG-ADM1-8247537B41623266        AFG
# 1     None     None      None  None  AFG-ADM1-8247537B78184625        AFG
# 2     None     None      None  None  AFG-ADM1-8247537B74530288        AFG
# 3     None     None      None  None  AFG-ADM1-8247537B30575277        AFG
# 4     None     None      None  None  AFG-ADM1-8247537B29636249        AFG
# ...    ...      ...       ...   ...                        ...        ...
# 3204  None     None       Fct  None  NGA-ADM1-2878026B56994386        NGA
# 3205  None     None   Bayelsa  None  NGA-ADM1-2878026B52218734        NGA
# 3206  None     None     Enugu  None  NGA-ADM1-2878026B43454599        NGA
# 3207  None     None     Lagos  None  NGA-ADM1-2878026B82395638        NGA
# 3208  None     None    Ebonyi  None  NGA-ADM1-2878026B29054847        NGA
#
#      shapeType      Country
# 0         ADM1  Afghanistan
# 1         ADM1  Afghanistan
# 2         ADM1  Afghanistan
# 3         ADM1  Afghanistan
# 4         ADM1  Afghanistan
# ...        ...          ...
# 3204      ADM1      Nigeria
# 3205      ADM1      Nigeria
# 3206      ADM1      Nigeria
# 3207      ADM1      Nigeria
# 3208      ADM1      Nigeria
#
# [3202 rows x 8 columns]
